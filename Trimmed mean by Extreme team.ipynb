# %%
lista = []
cantidad = int(input("How many data do you have?: "))
c=cantidad
i=1
sumL=0

while (cantidad>0):
    numero=float(input("Number #"+ str(i) + ": "))
    lista.append(numero)
    i=i+1
    cantidad = cantidad-1
    sumL=sumL+numero

for recorrido in range(1,len(lista)):
    for posicion in range(len(lista)-recorrido):
        if(lista[posicion]>lista[posicion+1]):
            temp=lista[posicion]
            lista[posicion]= lista[posicion+1]
            lista[posicion+1]= temp
print(lista)

porcentaje= int(input("What is your porcentage? "))
p=porcentaje/100
x=round(p*c)
if(x==1):
    a=lista.pop(0)
    d=lista.pop(-1)
    print(lista)
    sumwl=sumL-a-d
    tm=sumwl/(c-(x*2))
    print("Your trimmed mean is: ",tm)
if(x==2):
    a=lista.pop(0)
    b=lista.pop(-1)
    d=lista.pop(0)
    e=lista.pop(-1)
    print(lista)
    sumwl=sumL-a-d-b-e
    tm=sumwl/(c-(x*2))
    print("Your trimmed mean is: ",tm)
if(x==3):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    print(lista)
    sumwl=sumL-a-d-b-e-w-q
    tm=sumwl/(c-(x*2))
    print("Your trimmed mean is: ",tm)
if(x==4):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-0)
    print(lista)
    sumwl=sumL-a-d-b-e-w-q-r-t
    tm=sumwl/(c-(x*2))
    print("Your trimmed mean is: ",tm)
if(x==5):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    print(lista)
    sumwl=sumL-a-d-b-e-w-q-r-t-y-u
    tm=sumwl/(c-(x*2))
    print("Your trimmed mean is: ",tm)
if(x==6):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    s=lista.pop(0)
    f=lista.pop(-1)
    print(lista)
    sumwl=sumL-a-d-b-e-w-q-r-t-y-u-s-f
    tm=sumwl/(c-(x*2))
    print("Your trimmed mean is: ",tm)
if(x==7):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    s=lista.pop(0)
    f=lista.pop(-1)
    g=lista.pop(0)
    h=lista.pop(-1)
    print(lista)
    sumwl=sumL-a-d-b-e-w-q-r-t-y-u-s-f-g-h
    tm=sumwl/(c-(x*2))
    print("Your trimmed mean is: ",tm)
if(x==8):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    s=lista.pop(0)
    f=lista.pop(-1)
    g=lista.pop(0)
    h=lista.pop(-1)
    j=lista.pop(0)
    k=lista.pop(-1)
    print(lista)
    sumwl=sumL-a-d-b-e-w-q-r-t-y-u-s-f-g-h-j-k
    tm=sumwl/(c-(x*2))
    print("Your trimmed mean is: ",tm)
if(x==9):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    s=lista.pop(0)
    f=lista.pop(-1)
    g=lista.pop(0)
    h=lista.pop(-1)
    j=lista.pop(0)
    k=lista.pop(-1)
    l=lista.pop(0)
    ñ=lista.pop(-1)
    print(lista)
    sumwl=sumL-a-d-b-e-w-q-r-t-y-u-s-f-g-h-j-k-l-ñ
    tm=sumwl/(c-(x*2))
    print("Your trimmed mean is: ",tm)
if(x==10):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    s=lista.pop(0)
    f=lista.pop(-1)
    g=lista.pop(0)
    h=lista.pop(-1)
    j=lista.pop(0)
    k=lista.pop(-1)
    l=lista.pop(0)
    ñ=lista.pop(-1)
    n=lista.pop(0)
    m=lista.pop(-1)
    print(lista)
    sumwl=sumL-a-d-b-e-w-q-r-t-y-u-s-f-g-h-j-k-l-ñ-n-m
    tm=sumwl/(c-(x*2))
    print("Your trimmed mean is: ",tm)
print("ERROR")
# Out:
# How many data do you have?: 20
# Number #1: 1
# Number #2: 3
# Number #3: 2
# Number #4: 6
# Number #5: 5
# Number #6: 4
# Number #7: 8
# Number #8: 7
# Number #9: 9
# Number #10: 10
# Number #11: 4
# Number #12: 7
# Number #13: 9
# Number #14: 10
# Number #15: 15
# Number #16: 16
# Number #17: 18
# Number #18: 14
# Number #19: 13
# Number #20: 56
# [1.0, 2.0, 3.0, 4.0, 4.0, 5.0, 6.0, 7.0, 7.0, 8.0, 9.0, 9.0, 10.0, 10.0, 13.0, 14.0, 15.0, 16.0, 18.0, 56.0]
# What is your porcentage? 15
# [4.0, 4.0, 5.0, 6.0, 7.0, 7.0, 8.0, 9.0, 9.0, 10.0, 10.0, 13.0, 14.0, 15.0]
# Your trimmed mean is:  8.642857142857142
# ERROR

# %%
    porcentaje= int(input("What is your porcentage? "))
    p=porcentaje/100
    x=round(p*c)
    if(x<=16):
        mayor=max(lista)
        menor=min(lista)
        lista.remove(mayor)
        lista.remove(menor)
        print(lista)
        sumwl=(sumL-mayor)-menor
        tm=sumwl/(c-(x*2))
        print("Your trimmed mean is: ",tm)

# %%
lista = []
cantidad = int(input("How many data do you have?: "))
c=cantidad
mayor= 0
menor = 0
i=1
sumL=0
while (cantidad>0):
    numero=float(input("Number #"+ str(i) + ": "))
    lista.append(numero)
    i=i+1
    cantidad = cantidad-1
    sumL=sumL+numero

for recorrido in range(1,len(lista)):
    for posicion in range(len(lista)-recorrido):
        if(lista[posicion]>lista[posicion+1]):
            temp=lista[posicion]
            lista[posicion]= lista[posicion+1]
            lista[posicion+1]= temp
print(lista)
porcentaje= int(input("What is your porcentage? "))
p=porcentaje/100
x=round(p*c)
mayor=max(lista)
menor=min(lista)
lista.pop(0)
lista.pop(1)
lista.pop(-1)
lista.pop()
print(lista)

sumwl=(sumL-mayor)-menor
tm=sumwl/(c-(x*2))
print("Your trimmed mean is: ",tm)
